# %% [markdown]
# # Screening & Prediction
#
# Use the trained CGCNN to rank unseen/hypothetical materials from graph files.
#
# ## CLI Equivalent
#
# ```bash
# python scripts/screening.py \
#   --graphs-dir graphs/ \
#   --checkpoint models/cgcnn_fe/best.pt \
#   --output results/top_candidates.csv
# ```
