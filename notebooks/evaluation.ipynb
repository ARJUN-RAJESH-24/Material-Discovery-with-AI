# %% [markdown]
# # Evaluation & Comparison
#
# Analyze CGCNN vs baseline models. Generate parity plots, error histograms, and learning curves.
#
# ## Checklist
# - Load `results/cgcnn_metrics.json`
# - Load baseline metrics (`*.metrics.json`)
# - Plot parity of predictions vs actual
# - Compare MAE and R^2 across models
